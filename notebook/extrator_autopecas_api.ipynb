# %%
# !pip install transformers peft bitsandbytes trl accelerate -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 863.2/863.2 kB 45.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 30.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 16.8 MB/s eta 0:00:00

# %%
# !pip install fastapi uvicorn nest_asyncio -q

# %% [markdown]
# #É necessário carregar api/main.py e a pasta lora_adapter

# %%
import nest_asyncio
import uvicorn
from threading import Thread

nest_asyncio.apply()

from main import app

config = uvicorn.Config(app, host="0.0.0.0", port=8000, log_level="info")
server = uvicorn.Server(config)

thread_servidor = Thread(target=server.run, daemon=True)
thread_servidor.start()

import time
time.sleep(3)
print("Servidor rodando na porta 8000")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/660 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.09GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/338 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# ...

# %%
import requests
resposta = requests.post(
    "http://127.0.0.1:8000/extrair",
    json={"texto": "Amortecedor traseiro original Honda Civic 2010 a 2015"}
)
print(resposta.status_code)
print(resposta.json())
# Out:
# INFO:     127.0.0.1:45728 - "POST /extrair HTTP/1.1" 200 OK
# 200
# {'categoria': 'amortecedor', 'marca_veiculo': 'Honda', 'modelo_veiculo': 'Civic', 'ano_compativel': '2010-2015', 'posicao': None}

# %%
server.should_exit = True
